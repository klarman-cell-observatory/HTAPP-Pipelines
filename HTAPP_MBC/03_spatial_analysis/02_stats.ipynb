# %%
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import scanpy as sc
import anndata
import os
import sys

# %%
sys.path.insert(1, '/secure/projects/tacco/')
import tacco as tc

# %%
sys.path.insert(1, '/secure/projects/HTAPP_MBC/src/spatial')
from spatial_utils import *

# %%
plots_dir=out_dir_base+"/plots/"
os.makedirs(plots_dir, exist_ok=True)

# %%
sample_sheet=pd.read_csv(codeDir+"/meta/sampletracking_HTAPP_MBC_spatial.csv")

# %%
#These identifiers are set as defaults in many functions. If names are changed, this has to be adapted when calling the functions.
ct_column='cell_type'
sm_methods=["slide_seq","merfish","merfish_bin","codex","exseq","exseq_bin"] #spatial mathod names are hard-coded for now because some methods need special treatments. Can be fixed by giving eatch method it's own variable.
sc_method="scRNAseq"
all_methods=[sc_method,*sm_methods]
all_methods
# Out:
# ['scRNAseq',
#  'slide_seq',
#  'merfish',
#  'merfish_bin',
#  'codex',
#  'exseq',
#  'exseq_bin']

# %%
run_samples=list(filter(lambda a: not a in [], list(sample_sheet['sample'].unique()))) 
run_samples
# Out:
# ['HTAPP-944-SMP-7479',
#  'HTAPP-895-SMP-7359',
#  'HTAPP-880-SMP-7179',
#  'HTAPP-878-SMP-7149',
#  'HTAPP-812-SMP-8239',
#  'HTAPP-514-SMP-6760',
#  'HTAPP-982-SMP-7629',
#  'HTAPP-997-SMP-7789',
#  'HTAPP-917-SMP-4531',
#  'HTAPP-853-SMP-4381',
#  'HTAPP-313-SMP-932',
#  'HTAPP-330-SMP-1082',
#  'HTAPP-783-SMP-4081',
#  'HTAPP-364-SMP-1321',
#  'HTAPP-213-SMP-6752']

# %%
res=pd.DataFrame()
obs_all=pd.DataFrame()
for sample in run_samples:
    print(sample)
    out_dir=out_dir_base+"/"+sample 
    adatas=get_and_process_data(sample,data_dir,out_dir,methods=all_methods,process=False,verbose=False)
    for idx in adatas.index.to_list():
        obs=adatas[idx].obs
        tmp=adatas[idx].obs.groupby(adatas[idx].obs["replicate"].astype(str)).agg({ 'n_counts' : ['median','mean','min','max'], 'n_genes' : ['median','mean','min','max','count']})
        try: 
            total_genes=adatas[idx].obsm['counts'].shape[1]
        except: 
            continue
        obs['sample']=sample
        obs['method']=idx
        tmp['sample']=sample
        tmp['method']=idx
        tmp['total_genes']=total_genes
        tmp['ALB']='ALB' in adatas[idx].uns['counts_var']
        res=pd.concat([res,tmp])
        obs_all=pd.concat([obs_all,obs])
# Out:
# HTAPP-944-SMP-7479
# HTAPP-895-SMP-7359
# HTAPP-880-SMP-7179
# HTAPP-878-SMP-7149
# HTAPP-812-SMP-8239
# HTAPP-514-SMP-6760
# HTAPP-982-SMP-7629
# HTAPP-997-SMP-7789
# HTAPP-917-SMP-4531
# HTAPP-853-SMP-4381
# HTAPP-313-SMP-932
# HTAPP-330-SMP-1082
# HTAPP-783-SMP-4081
# HTAPP-364-SMP-1321
# HTAPP-213-SMP-6752

# %%
res
# Out:
#                n_counts                                        n_genes  \
#                  median          mean         min          max  median
# replicate
# 1           2748.000000   3281.706055  301.000000   19949.0000  2114.0
# 2           3126.000000   3614.295166  308.000000   19771.0000  2363.0
# 1            382.500000    565.534607   30.000000    5332.0000   308.0
# 1             45.000000     53.079563   20.000000     320.0000    25.0
# 2             53.000000     64.117752   20.000000     537.0000    28.0
# ...                 ...           ...         ...          ...     ...
# 1           2428.000000   3314.817871  304.000000   19986.0000  1842.0
# 2           2175.000000   2989.522949  487.000000   19914.0000  1753.0
# 1            137.000000    209.913895   55.000000    3227.0000   116.0
# 2            141.000000    202.246078   55.000000    3697.0000   121.0
# 1          30714.513672  34286.921875    1.938856  820270.8125    50.0
#
#                                                       sample     method  \
#                   mean  min   max  count
# replicate
# 1          2240.537436  218  7898   5476  HTAPP-944-SMP-7479   scRNAseq
# 2          2460.665639  288  7942   4540  HTAPP-944-SMP-7479   scRNAseq
# 1           408.561983   30  2745   9422  HTAPP-944-SMP-7479  slide_seq
# 1            26.713592    5    82   9263  HTAPP-944-SMP-7479    merfish
# 2            29.910880    7    99  11176  HTAPP-944-SMP-7479    merfish
# ...                ...  ...   ...    ...                 ...        ...
# 1          2202.154277  293  7595   4641  HTAPP-213-SMP-6752   scRNAseq
# 2          2097.886778  137  7942   5158  HTAPP-213-SMP-6752   scRNAseq
# 1           169.714789   41  2053   3124  HTAPP-213-SMP-6752  slide_seq
# 2           166.481404   40  2976   6238  HTAPP-213-SMP-6752  slide_seq
# 1            48.453101    1    50  26685  HTAPP-213-SMP-6752      codex
#
#           total_genes    ALB
#
# replicate
# 1               25811   True
# 2               25811   True
# 1               19365   True
# 1                 291  False
# 2                 291  False
# ...               ...    ...
# 1               25083  False
# 2               25083  False
# 1               17369  False
# 2               17369  False
# 1                  50  False
#
# [103 rows x 13 columns]

# %%
res_idx=res.reset_index().set_index(['sample'])

# %%
res_idx.columns = ['replicate','median_umis','mean_umis','min_umis','max_umis','median_genes','mean_genes','min_genes','max_genes','observations','method','total_genes','ALB']

# %%
res_idx.to_csv(plots_dir+"/stats.tsv",sep="\t")

# %%
res_idx[res_idx.method=="exseq"]
# Out:
#                    replicate  median_umis   mean_umis  min_umis  max_umis  \
# sample
# HTAPP-895-SMP-7359         1        186.0  275.799194      51.0    4432.0
# HTAPP-982-SMP-7629         1         44.0   58.442543      20.0     614.0
#
#                     median_genes  mean_genes  min_genes  max_genes  \
# sample
# HTAPP-895-SMP-7359          52.0    60.58539          5        263
# HTAPP-982-SMP-7629          29.0    32.90663          6        138
#
#                     observations method  total_genes    ALB
# sample
# HTAPP-895-SMP-7359          2998  exseq          297  False
# HTAPP-982-SMP-7629          1810  exseq          299   True

# %%
res_idx[res_idx.method=="exseq_bin"]
# Out:
#                    replicate  median_umis  mean_umis  min_umis  max_umis  \
# sample
# HTAPP-982-SMP-7629         1         52.0  60.893864      20.0     193.0
#
#                     median_genes  mean_genes  min_genes  max_genes  \
# sample
# HTAPP-982-SMP-7629          33.0    34.94464          6         85
#
#                     observations     method  total_genes   ALB
# sample
# HTAPP-982-SMP-7629          2836  exseq_bin          299  True

# %%
res_idx[res_idx.method=="merfish"]
# Out:
#                    replicate  median_umis   mean_umis  min_umis  max_umis  \
# sample
# HTAPP-944-SMP-7479         1         45.0   53.079563      20.0     320.0
# HTAPP-944-SMP-7479         2         53.0   64.117752      20.0     537.0
# HTAPP-944-SMP-7479         3         74.0   86.597412      20.0     658.0
# HTAPP-880-SMP-7179         2        210.0  223.167038      20.0    1102.0
# HTAPP-878-SMP-7149         2         66.0   83.852280      20.0     682.0
# HTAPP-812-SMP-8239         1         64.0   82.377930      20.0     575.0
# HTAPP-514-SMP-6760         2         85.0  102.805679      20.0     750.0
# HTAPP-982-SMP-7629         1         61.0   67.675072      20.0     340.0
# HTAPP-982-SMP-7629         2         53.0   59.160145      20.0     225.0
# HTAPP-917-SMP-4531         2        115.0  125.146294      20.0     624.0
# HTAPP-853-SMP-4381         1        107.0  117.742233      20.0     516.0
# HTAPP-313-SMP-932          1         65.0   77.078583      20.0     588.0
#
#                     median_genes  mean_genes  min_genes  max_genes  \
# sample
# HTAPP-944-SMP-7479          25.0   26.713592          5         82
# HTAPP-944-SMP-7479          28.0   29.910880          7         99
# HTAPP-944-SMP-7479          35.0   36.304332          4        117
# HTAPP-880-SMP-7179          60.0   58.361467          8        150
# HTAPP-878-SMP-7149          25.0   27.571818          3         99
# HTAPP-812-SMP-8239          29.0   31.679650          4        104
# HTAPP-514-SMP-6760          38.0   41.621910          5        135
# HTAPP-982-SMP-7629          30.0   31.004767          7         95
# HTAPP-982-SMP-7629          27.0   28.389848          6         80
# HTAPP-917-SMP-4531          47.0   46.408384          7        125
# HTAPP-853-SMP-4381          42.0   42.344675          6        104
# HTAPP-313-SMP-932           32.0   33.650583          4        100
#
#                     observations   method  total_genes    ALB
# sample
# HTAPP-944-SMP-7479          9263  merfish          291  False
# HTAPP-944-SMP-7479         11176  merfish          291  False
# HTAPP-944-SMP-7479         10758  merfish          291  False
# HTAPP-880-SMP-7179          3981  merfish          291  False
# HTAPP-878-SMP-7149         11014  merfish          291  False
# HTAPP-812-SMP-8239          3543  merfish          291  False
# HTAPP-514-SMP-6760         17636  merfish          291  False
# HTAPP-982-SMP-7629          7971  merfish          291  False
# HTAPP-982-SMP-7629          5851  merfish          291  False
# HTAPP-917-SMP-4531         11641  merfish          291  False
# HTAPP-853-SMP-4381          2704  merfish          291  False
# HTAPP-313-SMP-932          10549  merfish          291  False

# %%
res_idx[res_idx.method=="merfish_bin"]
# Out:
#                    replicate  median_umis   mean_umis  min_umis  max_umis  \
# sample
# HTAPP-944-SMP-7479         1         88.0   92.894646      20.0     290.0
# HTAPP-944-SMP-7479         2        110.0  116.754112      20.0     482.0
# HTAPP-944-SMP-7479         3        152.0  151.772064      20.0     432.0
# HTAPP-880-SMP-7179         2        206.0  216.663910      20.0     606.0
# HTAPP-878-SMP-7149         2         80.0   98.620728      20.0     518.0
# HTAPP-812-SMP-8239         1         73.0   84.388924      20.0     303.0
# HTAPP-514-SMP-6760         2        142.0  145.534439      20.0     504.0
# HTAPP-982-SMP-7629         1         97.0  102.048607      20.0     328.0
# HTAPP-982-SMP-7629         2         74.0   80.749046      20.0     260.0
# HTAPP-917-SMP-4531         2        174.0  172.121994      20.0     487.0
# HTAPP-853-SMP-4381         1        117.0  136.723343      20.0     456.0
# HTAPP-313-SMP-932          1         99.0  105.697296      20.0     354.0
#
#                     median_genes  mean_genes  min_genes  max_genes  \
# sample
# HTAPP-944-SMP-7479          41.0   41.239960          3         93
# HTAPP-944-SMP-7479          47.0   46.873757          5        119
# HTAPP-944-SMP-7479          57.0   54.086989          4        113
# HTAPP-880-SMP-7179          62.0   58.247188          6        124
# HTAPP-878-SMP-7149          29.0   31.570358          3        121
# HTAPP-812-SMP-8239          33.0   34.416884          3         84
# HTAPP-514-SMP-6760          57.0   54.856886          4        119
# HTAPP-982-SMP-7629          42.0   42.058004          6         87
# HTAPP-982-SMP-7629          36.0   36.088462          8         77
# HTAPP-917-SMP-4531          61.0   57.154659          5        110
# HTAPP-853-SMP-4381          46.0   45.647191          7        101
# HTAPP-313-SMP-932           42.0   41.346818          4         96
#
#                     observations       method  total_genes    ALB
# sample
# HTAPP-944-SMP-7479         25846  merfish_bin          291  False
# HTAPP-944-SMP-7479         29269  merfish_bin          291  False
# HTAPP-944-SMP-7479         27153  merfish_bin          291  False
# HTAPP-880-SMP-7179         12092  merfish_bin          291  False
# HTAPP-878-SMP-7149         40024  merfish_bin          291  False
# HTAPP-812-SMP-8239         16453  merfish_bin          291  False
# HTAPP-514-SMP-6760         65053  merfish_bin          291  False
# HTAPP-982-SMP-7629         28636  merfish_bin          291  False
# HTAPP-982-SMP-7629         20992  merfish_bin          291  False
# HTAPP-917-SMP-4531         42959  merfish_bin          291  False
# HTAPP-853-SMP-4381         12015  merfish_bin          291  False
# HTAPP-313-SMP-932          41480  merfish_bin          291  False

# %%
res_idx[res_idx.method=="slide_seq"]
# Out:
#                    replicate  median_umis   mean_umis  min_umis  max_umis  \
# sample
# HTAPP-944-SMP-7479         1        382.5  565.534607      30.0    5332.0
# HTAPP-895-SMP-7359         1        380.0  607.814514      30.0    7112.0
# HTAPP-880-SMP-7179         1        172.0  257.291626      46.0    8360.0
# HTAPP-880-SMP-7179         2        115.0  159.678070      45.0    1845.0
# HTAPP-878-SMP-7149         1        113.0  139.779221      63.0     939.0
# HTAPP-878-SMP-7149         2        133.0  174.173035      63.0    1303.0
# HTAPP-812-SMP-8239         1        160.0  236.366730      51.0    2162.0
# HTAPP-812-SMP-8239         2        123.0  165.751892      52.0    1894.0
# HTAPP-514-SMP-6760         1        178.0  281.985077      30.0    3711.0
# HTAPP-514-SMP-6760         2        217.0  339.457336      30.0    4826.0
# HTAPP-982-SMP-7629         1        179.0  367.364197      33.0    5184.0
# HTAPP-997-SMP-7789         1        169.0  262.813049      48.0    2794.0
# HTAPP-997-SMP-7789         2        163.0  241.722153      48.0    2175.0
# HTAPP-917-SMP-4531         2        202.0  298.781769      39.0    3477.0
# HTAPP-853-SMP-4381         1        176.0  279.119324      45.0    2473.0
# HTAPP-853-SMP-4381         2        174.0  272.806305      46.0    2511.0
# HTAPP-313-SMP-932          1        189.0  273.537506      53.0    3014.0
# HTAPP-313-SMP-932          2        135.0  182.144424      54.0    1455.0
# HTAPP-330-SMP-1082         2        150.0  221.077377      38.0    2106.0
# HTAPP-783-SMP-4081         1        126.0  165.369308      63.0    1227.0
# HTAPP-783-SMP-4081         2        132.0  175.862030      63.0    2455.0
# HTAPP-364-SMP-1321         1        119.5  154.045074      68.0    1120.0
# HTAPP-364-SMP-1321         2        122.0  160.896439      68.0    1418.0
# HTAPP-213-SMP-6752         1        137.0  209.913895      55.0    3227.0
# HTAPP-213-SMP-6752         2        141.0  202.246078      55.0    3697.0
#
#                     median_genes  mean_genes  min_genes  max_genes  \
# sample
# HTAPP-944-SMP-7479         308.0  408.561983         30       2745
# HTAPP-895-SMP-7359         282.0  402.293076         30       3111
# HTAPP-880-SMP-7179         138.0  192.873423         30       5437
# HTAPP-880-SMP-7179          92.0  124.332941         30       1181
# HTAPP-878-SMP-7149          96.0  116.847402         37        644
# HTAPP-878-SMP-7149         114.0  144.271372         35        990
# HTAPP-812-SMP-8239         137.0  190.174255         35       1343
# HTAPP-812-SMP-8239         105.0  136.282269         35       1206
# HTAPP-514-SMP-6760         163.0  241.086196         30       2335
# HTAPP-514-SMP-6760         195.0  281.756426         30       2579
# HTAPP-982-SMP-7629         144.0  256.052065         30       2569
# HTAPP-997-SMP-7789         137.0  197.619056         32       1713
# HTAPP-997-SMP-7789         132.0  186.997622         32       1306
# HTAPP-917-SMP-4531         163.0  229.794148         30       2007
# HTAPP-853-SMP-4381         146.0  212.738721         31       1438
# HTAPP-853-SMP-4381         145.0  210.520478         32       1500
# HTAPP-313-SMP-932          165.0  222.615493         31       1751
# HTAPP-313-SMP-932          119.0  155.536192         43       1023
# HTAPP-330-SMP-1082         117.0  159.375918         30       1202
# HTAPP-783-SMP-4081          89.0  111.938683         37        900
# HTAPP-783-SMP-4081          94.0  118.755623         34       1487
# HTAPP-364-SMP-1321          98.0  120.868990         46        901
# HTAPP-364-SMP-1321          97.5  124.128284         43        843
# HTAPP-213-SMP-6752         116.0  169.714789         41       2053
# HTAPP-213-SMP-6752         121.0  166.481404         40       2976
#
#                     observations     method  total_genes    ALB
# sample
# HTAPP-944-SMP-7479          9422  slide_seq        19365   True
# HTAPP-895-SMP-7359          6210  slide_seq        18107  False
# HTAPP-880-SMP-7179         12838  slide_seq        17731   True
# HTAPP-880-SMP-7179          9350  slide_seq        17731   True
# HTAPP-878-SMP-7149          7949  slide_seq        19041  False
# HTAPP-878-SMP-7149         14084  slide_seq        19041  False
# HTAPP-812-SMP-8239          6479  slide_seq        16746  False
# HTAPP-812-SMP-8239          4478  slide_seq        16746  False
# HTAPP-514-SMP-6760         17437  slide_seq        20944  False
# HTAPP-514-SMP-6760         15835  slide_seq        20944  False
# HTAPP-982-SMP-7629          8086  slide_seq        17223   True
# HTAPP-997-SMP-7789          5846  slide_seq        18368   True
# HTAPP-997-SMP-7789          5046  slide_seq        18368   True
# HTAPP-917-SMP-4531          8715  slide_seq        16522   True
# HTAPP-853-SMP-4381          5741  slide_seq        17292   True
# HTAPP-853-SMP-4381          5689  slide_seq        17292   True
# HTAPP-313-SMP-932           5654  slide_seq        17023   True
# HTAPP-313-SMP-932           5830  slide_seq        17023   True
# HTAPP-330-SMP-1082         11851  slide_seq        16811   True
# HTAPP-783-SMP-4081          2854  slide_seq        13553  False
# HTAPP-783-SMP-4081          2979  slide_seq        13553  False
# HTAPP-364-SMP-1321          1664  slide_seq        12433   True
# HTAPP-364-SMP-1321          1294  slide_seq        12433   True
# HTAPP-213-SMP-6752          3124  slide_seq        17369  False
# HTAPP-213-SMP-6752          6238  slide_seq        17369  False

# %%
res_idx.loc[res_idx.method=="codex",["replicate","observations"]]
# Out:
#                    replicate  observations
# sample
# HTAPP-880-SMP-7179         2         21019
# HTAPP-878-SMP-7149         2         32070
# HTAPP-812-SMP-8239         2         12815
# HTAPP-514-SMP-6760         2         35995
# HTAPP-982-SMP-7629         2         19246
# HTAPP-997-SMP-7789         1         22587
# HTAPP-917-SMP-4531         2         35867
# HTAPP-853-SMP-4381         1         14710
# HTAPP-313-SMP-932          1         30005
# HTAPP-330-SMP-1082         2         36888
# HTAPP-783-SMP-4081         1          5711
# HTAPP-364-SMP-1321         1         19000
# HTAPP-213-SMP-6752         1         26685
